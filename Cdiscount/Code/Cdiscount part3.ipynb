# 4727  https://www.cdiscount.com/maison/lampes/youokl...
# 4728  https://www.cdiscount.com/maison/lampes/youokl...
# 4729  https://www.cdiscount.com/maison/lampes/youokl...
# 4730  https://www.cdiscount.com/maison/lampes/youokl...
# 4731  https://www.cdiscount.com/maison/lampes/youokl...
# 4732  https://www.cdiscount.com/maison/lampes/youokl...
# 4733  https://www.cdiscount.com/maison/lampes/youokl...
# 4734  https://www.cdiscount.com/maison/lampes/ywei-l...
# 4735  https://www.cdiscount.com/maison/meubles-mobil...
# 4736  https://www.cdiscount.com/sante-mieux-vivre/mi...
#
# [4737 rows x 1 columns]

# %%
url_spots=[]
for i in range(len(Liens_spots)):
    url_spots.append(Liens_spots.iloc[i]["Liens"])



html = pd.read_html(url_spots[0])
df = html[0]

df = pd.DataFrame(df).T
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df hea

df = df.loc[:,~df.columns.duplicated()]
print(df)




df3=[]
tabless=[]
for i in range(len(Liens_spots)):    
    try:
        html = pd.read_html(url_spots[i])
        
    except ValueError:
        print(url_spots[i])
        pass
        
    df2=html[0]
    
    df3.append(pd.DataFrame(df2).T)
    new_head = df3[i].iloc[0]
    df3[i] = df3[i][1:]
    df3[i].columns=new_head   
    
    df3[i] = df3[i].loc[:,~df3[i].columns.duplicated()]
    
    for c in df3[i].columns:
        if c not in df.columns:
            df[c] = None
    for c in df.columns:
        if c not in df3[i].columns:
            df3[i][c] = None
df_final=pd.DataFrame.append(df, df3, sort=True)
df_final 


pd.DataFrame.to_excel(df_final, "Spots.xlsx", sheet_name='Sheet1', header=True, index=None)
# Out:
# Informations générales sur le produit      Marque  \
# Informations générales sur le produit.1  INOVTECH
#
# Informations générales sur le produit                          Nom du produit  \
# Informations générales sur le produit.1  INOVTECH Spot Tulipe à Leds Flexible
#
# Informations générales sur le produit                 Catégorie  \
# Informations générales sur le produit.1  SPOTS - LIGNE DE SPOTS
#
# Informations générales sur le produit    Spécificités Web Déstockage  Général  \
# Informations générales sur le produit.1  Spécificités Web Déstockage  Général
#
# Informations générales sur le produit   Vintage  Type d'ampoule  \
# Informations générales sur le produit.1     Non  Type d'ampoule
#
# Informations générales sur le produit   Forme de l'ampoule  \
# Informations générales sur le produit.1  Réflecteur - Spot
#
# Informations générales sur le produit   Technologie de l'ampoule  \
# Informations générales sur le produit.1                      LED
#
# Informations générales sur le produit   Puissance en w Couleur de l'ampoule  \
# Informations générales sur le produit.1            2 W                Blanc
#
# Informations générales sur le produit   Musique Détecteur de mouvement  \
# Informations générales sur le produit.1     Non                    Non
#
# Informations générales sur le produit    Alimentation  \
# Informations générales sur le produit.1  Alimentation
#
# Informations générales sur le produit   Mode de mise en marche - arrêt
# Informations générales sur le produit.1                   Interrupteur
# https://www.cdiscount.com/maison/lampes/hemlock-spot-chrome-2x40w/f-1170210-phi8718696133163.html
# https://www.cdiscount.com/maison/lampes/hemlock-spot-chrome-3x40w/f-1170210-phi8718696133170.html
# https://www.cdiscount.com/maison/lampes/rastaban-plafonnier-spot-blanc-1x20w/f-1170210-phi8718696126127.html
# https://www.cdiscount.com/maison/lampes/spot-encastrable-led-gx53-megatron-mt76540-6-5-w/f-1170210-auc4020856765409.html
